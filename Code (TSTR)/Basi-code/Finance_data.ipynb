# %% [markdown]
# #Finance_data.csv

# %%
import pandas as pd
path = '/content/drive/MyDrive/Durgesh(testing)/Data augmentation/27 05 2025/Finance_data.csv'
df = pd.read_csv(path)
df.head(20)
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.dtypes
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
def classify_ranges(series):
    if pd.api.types.is_numeric_dtype(series):
        min = series.min()
        max = series.max()
        if min == 1 and max == 1:
            return "1 -> refine"
        elif 0 <= min and max <= 1:
            return "0–1 - normalize"
        else:
            return f"{min}-{max} -> consider scaling"
    else:
        return "non-numeric -> consider encoding"
print('value range classification:')
df.apply(classify_ranges)
# Out:
# value range classification:
# gender                               non-numeric -> consider encoding
# age                                         21-35 -> consider scaling
# Investment_Avenues                   non-numeric -> consider encoding
# Mutual_Funds                                  1-7 -> consider scaling
# Equity_Market                                 1-6 -> consider scaling
# Debentures                                    1-7 -> consider scaling
# Government_Bonds                              1-7 -> consider scaling
# Fixed_Deposits                                1-7 -> consider scaling
# PPF                                           1-6 -> consider scaling
# Gold                                          2-7 -> consider scaling
# Stock_Marktet                        non-numeric -> consider encoding
# Factor                               non-numeric -> consider encoding
# Objective                            non-numeric -> consider encoding
# ...
