# %% [markdown]
# #Product.csv

# %%
import pandas as pd
path = '/content/drive/MyDrive/Durgesh(testing)/Data augmentation/27 05 2025/Product.csv'
df = pd.read_csv(path)
df.head(20)
# Out:
#     Product ID                                      Product Title  \
# 0            1                    apple iphone 8 plus 64gb silver
# 1            2                apple iphone 8 plus 64 gb spacegrau
# 2            3  apple mq8n2b/a iphone 8 plus 64gb 5.5 12mp sim...
# 3            4                apple iphone 8 plus 64gb space grey
# 4            5  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
# 5            6  apple iphone 8 plus gold 5.5 64gb 4g unlocked ...
# 6            7               apple iphone 8 plus 64 gb space grey
# 7            8                apple iphone 8 plus 64gb space grey
# 8            9                apple iphone 8 plus 64gb space grey
# 9           10                apple iphone 8 plus 64gb space grey
# 10          11  apple iphone 8 plus 5.5 single sim 4g 64gb silver
# 11          12    sim free iphone 8 plus 64gb by apple space grey
# 12          13           apple iphone 8 plus 64gb gold smartphone
# ...

# %%
df.dtypes
# Out:
# Product ID          int64
# Product Title      object
#  Merchant ID        int64
#  Cluster ID         int64
#  Cluster Label     object
#  Category ID        int64
#  Category Label    object
# dtype: object

# %%
df.describe()
# Out:
#          Product ID   Merchant ID    Cluster ID   Category ID
# count  35311.000000  35311.000000  35311.000000  35311.000000
# mean   26150.800176    120.501883  30110.687633   2618.142930
# std    13498.191220    117.045557  18410.265642      3.600708
# min        1.000000      1.000000      1.000000   2612.000000
# 25%    14958.500000     17.000000   6123.000000   2615.000000
# 50%    27614.000000     75.000000  40630.000000   2619.000000
# 75%    37508.500000    253.000000  44059.000000   2622.000000
# max    47358.000000    371.000000  47525.000000   2623.000000

# %%
def classify_ranges(series):
    if pd.api.types.is_numeric_dtype(series):
        min = series.min()
        max = series.max()
        if min == 1 and max == 1:
            return "1 -> refine"
        elif 0 <= min and max <= 1:
            return "0–1 - normalize"
        else:
            return f"{min}-{max} -> consider scaling"
    else:
        return "non-numeric -> consider encoding"
print('value range classification:')
df.apply(classify_ranges)
# Out:
# value range classification:
# Product ID              1-47358 -> consider scaling
# Product Title      non-numeric -> consider encoding
#  Merchant ID              1-371 -> consider scaling
#  Cluster ID             1-47525 -> consider scaling
#  Cluster Label     non-numeric -> consider encoding
#  Category ID          2612-2623 -> consider scaling
#  Category Label    non-numeric -> consider encoding
# dtype: object
