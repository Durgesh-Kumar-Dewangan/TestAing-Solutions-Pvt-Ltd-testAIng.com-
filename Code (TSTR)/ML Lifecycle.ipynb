# %% [markdown]
# Problem definition
# Predict EV adoption Share states as high or low Ev adoption

# %%
import pandas as pd
Path = '/content/drive/MyDrive/Durgesh(testing)/Code (ML lifecycle)/EV_Data.csv'
Ev_adoption = pd.read_csv(Path)

# %%
Ev_adoption
# Out:
#      Unnamed: 0.1  Unnamed: 0       ex party  year  EV Registrations  \
# 0               0           0        Alabama  2023             13000
# 1               1           1         Alaska  2023              2700
# 2               2           2        Arizona  2023             89800
# 3               3           3       Arkansas  2023              7100
# 4               4           4     California  2023           1256600
# ..            ...         ...            ...   ...               ...
# 403           403         403       Virginia  2016              3100
# 404           404         404     Washington  2016             14900
# 405           405         405  West Virginia  2016               100
# 406           406         406      Wisconsin  2016              2600
# 407           407         407        Wyoming  2016               100
#
#      Total Vehicles  EV Share (%)  Stations  Total Charging Outlets  Level 1  \
# ...

# %%
Ev_adoption.dtypes
# Out:
# Unnamed: 0.1                               int64
# Unnamed: 0                                 int64
# state                                     object
# year                                       int64
# EV Registrations                           int64
# Total Vehicles                             int64
# EV Share (%)                             float64
# Stations                                   int64
# Total Charging Outlets                     int64
# Level 1                                    int64
# Level 2                                    int64
# DC Fast                                    int64
# fuel_economy                             float64
# Incentives                               float64
# Number of Metro Organizing Committees    float64
# Population_20_64                         float64
# Education_Bachelor                       float64
# Labour_Force_Participation_Rate          float64
# Unemployment_Rate                        float64
# ...

# %%
Ev_adoption.isnull()
# Out:
#      Unnamed: 0.1  Unnamed: 0  ex party   year  EV Registrations  \
# 0           False       False     False  False             False
# 1           False       False     False  False             False
# 2           False       False     False  False             False
# 3           False       False     False  False             False
# 4           False       False     False  False             False
# ..            ...         ...       ...    ...               ...
# 403         False       False     False  False             False
# 404         False       False     False  False             False
# 405         False       False     False  False             False
# 406         False       False     False  False             False
# 407         False       False     False  False             False
#
#      Total Vehicles  EV Share (%)  Stations  Total Charging Outlets  Level 1  \
# 0             False         False     False                   False    False
# ...

# %%
Ev_adoption.isna().sum()
# Out:
# Unnamed: 0.1                               0
# Unnamed: 0                                 0
# ex party                                   0
# year                                       0
# EV Registrations                           0
# Total Vehicles                             0
# EV Share (%)                               0
# Stations                                   0
# Total Charging Outlets                     0
# Level 1                                    0
# Level 2                                    0
# DC Fast                                    0
# fuel_economy                             102
# Incentives                                 8
# Number of Metro Organizing Committees     51
# Population_20_64                           0
# Education_Bachelor                         0
# Labour_Force_Participation_Rate            0
# Unemployment_Rate                          0
# Bachelor_Attainment                        0
# Per_Cap_Income                             0
# ...

# %%
Ev_adoption.dropna()
# Out:
#      Unnamed: 0.1  Unnamed: 0       ex party  year  EV Registrations  \
# 0               0           0        Alabama  2023             13000
# 1               1           1         Alaska  2023              2700
# 2               2           2        Arizona  2023             89800
# 3               3           3       Arkansas  2023              7100
# 4               4           4     California  2023           1256600
# ..            ...         ...            ...   ...               ...
# 301           301         301       Virginia  2018              9900
# 302           302         302     Washington  2018             30200
# 303           303         303  West Virginia  2018               200
# 304           304         304      Wisconsin  2018              3700
# 305           305         305        Wyoming  2018               200
#
#      Total Vehicles  EV Share (%)  Stations  Total Charging Outlets  Level 1  \
# ...

# %%
Ev_adoption.drop_duplicates()
# Out:
#      Unnamed: 0.1  Unnamed: 0          state  year  EV Registrations  \
# 0               0           0        Alabama  2023             13000
# 1               1           1         Alaska  2023              2700
# 2               2           2        Arizona  2023             89800
# 3               3           3       Arkansas  2023              7100
# 4               4           4     California  2023           1256600
# ..            ...         ...            ...   ...               ...
# 403           403         403       Virginia  2016              3100
# 404           404         404     Washington  2016             14900
# 405           405         405  West Virginia  2016               100
# 406           406         406      Wisconsin  2016              2600
# 407           407         407        Wyoming  2016               100
#
#      Total Vehicles  EV Share (%)  Stations  Total Charging Outlets  Level 1  \
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, state, year, EV Registrations, Total Vehicles, EV Share (%), Stations, Total Charging Outlets, Level 1, Level 2, DC Fast, fuel_economy, Incentives, Number of Metro Organizing Committees, Population_20_64, Education_Bachelor, Labour_Force_Participation_Rate, Unemployment_Rate, Bachelor_Attainment, Per_Cap_Income, affectweather, devharm, discuss, exp, localofficials, personal, reducetax, regulate, worried, price_cents_per_kwh, gasoline_price_per_gallon, Total, Trucks, Trucks_Share, Party]
# Index: []
#
# [0 rows x 36 columns]
